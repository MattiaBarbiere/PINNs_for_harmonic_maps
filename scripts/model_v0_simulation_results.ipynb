# %%
# Automatically reload modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulation study of the embedding layer of Model v0

# %%
# Import the relevant functions for loading and plotting
from hmpinn.plotting import plot_errors_in_grid, plot_errors_from_path

import seaborn as sns
#Setting theme
sns.set_theme(style="whitegrid")

# %% [markdown]
# Each model was trained on exactly 100 000 datapoints with 10 epochs and 100 batches, with each batch size begin 100

# %%
# All the paths for the embedding data
## I chose to use the batch size = 100 for this part
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/100 batches_1 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_2 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_4 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_6 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_8 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_10 embeddings_per_dim"
]
embeddings_per_dim_list = ["1 embeddings per dim" , "2 embeddings per dim" , 
                           "4 embeddings per dim" , "6 embeddings per dim" , 
                           "8 embeddings per dim" , "10 embeddings per dim"]

plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=embeddings_per_dim_list)

# %% [markdown]
# ## No embedding layer

# %%
path = "../simulation_studies/model_v0_simulation/outputs/100 batches_0 embeddings_per_dim"
title = "No Embeddings"
plot_errors_from_path(path, title=title)

# %% [markdown]
# # Epochs vs batchs

# %% [markdown]
# I will take that the emebedding per dim is 2.

# %%
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/1 batches_2 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/10 batches_2 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/100 batches_2 embeddings_per_dim",
    "../simulation_studies/model_v0_simulation/outputs/1000 batches_2 embeddings_per_dim",
]

batch_size_list = ["1 batch", "10 batches", "100 batches", "1000 batches"]
plot_errors_in_grid(path_list, number_of_rows=2, number_of_columns=2, title_list=batch_size_list)

# %% [markdown]
# So no difference, we in future models we will only use epochs and no epochs

# %% [markdown]
# # Model variations

# %% [markdown]
# The hidden layer variations I chose:
# - [64, 64]: Short and thin
# - [128, 128]: Short and quite wide
# - [512, 512]: Short and very wide
#
# - [128, 256, 128]: Medium and thinner
# - [128, 256, 512, 256, 128]: Medium and wide
# - [512, 512, 512, 512]: Medium and very wide
#
# - [64, 64, 64, 64, 64, 64]: Long and thin
# - [64, 128, 128, 128, 64]: Long and quite wide
# - [16, 64, 128, 256, 128, 64, 16]: Long and wide

# %%
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 256, 512, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[512, 512, 512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 64, 64, 64, 64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 128, 128, 128, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[16, 64, 128, 256, 128, 64, 16]",
]

hidden_layers_list = ["[64, 64]", "[128, 128]", "[512, 512]", "[128, 256, 128]",
                        "[128, 256, 512, 256, 128]", "[512, 512, 512, 512]",
                        "[64, 64, 64, 64, 64, 64]", "[64, 128, 128, 128, 64]",
                        "[16, 64, 128, 256, 128, 64, 16]"]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=3, title_list=hidden_layers_list)

# %% [markdown]
# ---

# %% [markdown]
# # Model Variations for Poisson problem with non symmetric diffusion

# %%
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[128, 256, 512, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[512, 512, 512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 64, 64, 64, 64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[64, 128, 128, 128, 64]",
    "../simulation_studies/model_v0_simulation/outputs/diff/model_[16, 64, 128, 256, 128, 64, 16]",
]

hidden_layers_list = ["[64, 64]", "[128, 128]", "[512, 512]", "[128, 256, 128]",
                        "[128, 256, 512, 256, 128]", "[512, 512, 512, 512]",
                        "[64, 64, 64, 64, 64, 64]", "[64, 128, 128, 128, 64]",
                        "[16, 64, 128, 256, 128, 64, 16]"]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=3, title_list=hidden_layers_list)

# %% [markdown]
# # Model Variations for Poisson problem with symmetric diffusion

# %%
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[128, 128]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[128, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[128, 256, 512, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[512, 512, 512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[64, 64, 64, 64, 64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[64, 128, 128, 128, 64]",
    "../simulation_studies/model_v0_simulation/outputs/sym_diff/model_[16, 64, 128, 256, 128, 64, 16]",
]

hidden_layers_list = ["[64, 64]", "[128, 128]", "[512, 512]", "[128, 256, 128]",
                        "[128, 256, 512, 256, 128]", "[512, 512, 512, 512]",
                        "[64, 64, 64, 64, 64, 64]", "[64, 128, 128, 128, 64]",
                        "[16, 64, 128, 256, 128, 64, 16]"]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=3, title_list=hidden_layers_list)

# %% [markdown]
# # Model Variations for Poisson problem with eigenfunction

# %%
path_list = [
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[128, 128]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[128, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[128, 256, 512, 256, 128]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[512, 512, 512, 512]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[64, 64, 64, 64, 64, 64]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[64, 128, 128, 128, 64]",
    "../simulation_studies/model_v0_simulation/outputs/eigenfunc/model_[16, 64, 128, 256, 128, 64, 16]",
]

hidden_layers_list = ["[64, 64]", "[128, 128]", "[512, 512]", "[128, 256, 128]",
                        "[128, 256, 512, 256, 128]", "[512, 512, 512, 512]",
                        "[64, 64, 64, 64, 64, 64]", "[64, 128, 128, 128, 64]",
                        "[16, 64, 128, 256, 128, 64, 16]"]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=3, title_list=hidden_layers_list)
