# %% [markdown]
# # Can we *heavily* weakly enforce boundary conditions

# %%
# Automatically reload modules
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
#Setting theme
sns.set_theme(style="whitegrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from hmpinn.plotting import plot_errors_in_grid, plot_model_vs_analytical_error

# %%
def show_abs_error(ratio, pde, title):
    path = f"../simulation_studies/weakly_enforcing_BC/outputs/{ratio}_{pde}_tanh"
    plot_model_vs_analytical_error(path, title=f"{title} ratio={ratio}")

# %% [markdown]
# ## Example 1: Eigenfunction

# %% [markdown]
# I will try to solve the following poisson problem
# \begin{equation}
# \Delta u = f(x, y)
# \end{equation}
#
# with boundary conditions:
#
# \begin{equation}
# u(0, y) = u(1, y) = u(x, 0) = u(x, 1) = 0
# \end{equation}
#
# where
#
# \begin{equation}
# f(x, y) = -\sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}
#
# Clear the analytical solution to this is
# \begin{equation}
# u(x, y) = \frac{1}{2 \pi^2} \sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}

# %%
for ratio in [0.5, 1.0, 4.0, 16.0, 64.0, 128.0]:
    show_abs_error(ratio, "eigenfunc", title="Eigenfunction")
# Out:
# e:\documents\epfl\semester project\hmpinn\hmpinn\plotting\plotting_errors.py:217: UserWarning: Log scale: values of z <= 0 have been masked
#   contour = plt.contourf(X, Y, res, cmap="YlOrRd", levels=levels_list, norm=LogNorm())

# %%
path_list = [
    "../simulation_studies/weakly_enforcing_BC/outputs/0.5_eigenfunc_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/1.0_eigenfunc_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/4.0_eigenfunc_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/16.0_eigenfunc_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/64.0_eigenfunc_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/128.0_eigenfunc_tanh",
]
title_list = ["Eigenfunction 0.5", "Eigenfunction 1.0",
              "Eigenfunction 4.0", "Eigenfunction 16.0",
              "Eigenfunction 64.0", "Eigenfunction 128.0",]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ## Example 2: Constant source term with complicated boundary condition

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \frac{\partial^2 u}{\partial x^2} + \frac{\partial^2 u}{\partial y^2} = 4
# \end{equation}
#
# with the boundary condition
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}

# %%
for ratio in [0.5, 1.0, 4.0, 16.0, 64.0, 128.0]:
    show_abs_error(ratio, "const_source", title="Constant Source")

# %%
path_list = [
    "../simulation_studies/weakly_enforcing_BC/outputs/0.5_const_source_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/1.0_const_source_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/4.0_const_source_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/16.0_const_source_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/64.0_const_source_tanh",
    "../simulation_studies/weakly_enforcing_BC/outputs/128.0_const_source_tanh",
]
title_list = ["Constant Source 0.5", "Constant Source 1.0",
              "Constant Source 4.0", "Constant Source 16.0",
              "Constant Source 64.0", "Constant Source 128.0",]
plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=title_list)
