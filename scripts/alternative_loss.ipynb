# %% [markdown]
# # Adding boundary condition to the loss instead of embedding layer

# %%
# Automatically reload modules
# %load_ext autoreload
# %autoreload 2

#Setting theme
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from hmpinn.plotting import plot_errors_in_grid, plot_model_vs_analytical_error

# %% [markdown]
# ---
# ---

# %% [markdown]
# # When is the best optimizer switch?
# Total epochs were 15000. Loss weight is 10

# %% [markdown]
# ## Fitting the eigenfunctions

# %% [markdown]
# I will try to solve the following poisson problem
# \begin{equation}
# \Delta u = f(x, y)
# \end{equation}
#
# with boundary conditions:
#
# \begin{equation}
# u(0, y) = u(1, y) = u(x, 0) = u(x, 1) = 0
# \end{equation}
#
# where
#
# \begin{equation}
# f(x, y) = -\sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}
#
# Clear the analytical solution to this is
# \begin{equation}
# u(x, y) = \frac{1}{2 \pi^2} \sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_3000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_3000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_12000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_12000_eigenfunc",

]
title_list = ["[20,20,20,20], switch at epoch = 3000", "[64,64,64,64,64,64], switch at epoch = 3000", 
              "[20,20,20,20], switch at epoch = 7000", "[64,64,64,64,64,64], switch at epoch = 7000",
              "[20,20,20,20], switch at epoch = 12000", "[64,64,64,64,64,64], switch at epoch = 12000"]

plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ---

# %% [markdown]
# ## Constant source term with complicated boundary condition

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \frac{\partial^2 u}{\partial x^2} + \frac{\partial^2 u}{\partial y^2} = 4
# \end{equation}
#
# with the boundary condition
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_3000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_3000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_12000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_12000_const_source",

]
title_list = ["[20,20,20,20], switch at epoch = 3000", "[64,64,64,64,64,64], switch at epoch = 3000", 
              "[20,20,20,20], switch at epoch = 7000", "[64,64,64,64,64,64], switch at epoch = 7000",
              "[20,20,20,20], switch at epoch = 12000", "[64,64,64,64,64,64], switch at epoch = 12000"]

plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ---

# %% [markdown]
# ## Non-constant diffusion matrix

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \nabla \cdot (k(x,y) \nabla u(x,y)) = f(x,y)
# \end{equation}
# with
#
# \begin{equation}
# k(x,y) = \begin{pmatrix}
# x + 2 & xy^2\\
# xy^2 & y + 3
# \end{pmatrix}
# \end{equation}
#
# and
#
# \begin{equation}
# f(x,y) = 3y^4+9y^2+4x^2y+18y+4x+4
# \end{equation}
#
#
#
# with the boundary condition
#
# \begin{equation}
# u(x,y)=x^2+y^3
# \end{equation}
#
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2+y^3
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_3000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_3000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[20, 20, 20, 20]_Adam_12000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/10 weight_[64, 64, 64, 64, 64, 64]_Adam_12000_non_const_BC",

]
title_list = ["[20,20,20,20], switch at epoch = 3000", "[64,64,64,64,64,64], switch at epoch = 3000", 
              "[20,20,20,20], switch at epoch = 7000", "[64,64,64,64,64,64], switch at epoch = 7000",
              "[20,20,20,20], switch at epoch = 12000", "[64,64,64,64,64,64], switch at epoch = 12000"]

plot_errors_in_grid(path_list, number_of_rows=3, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# If we have 15000 epochs the best time to switch is when we reach about half way $\approx$ 7000

# %% [markdown]
# ---
# ---

# %% [markdown]
# # What is the best boundary condition weight?

# %% [markdown]
# Total epochs were 15000. Optimizer switch at epoch 7000

# %% [markdown]
# ## Fitting the eigenfunctions

# %% [markdown]
# I will try to solve the following poisson problem
# \begin{equation}
# \Delta u = f(x, y)
# \end{equation}
#
# with boundary conditions:
#
# \begin{equation}
# u(0, y) = u(1, y) = u(x, 0) = u(x, 1) = 0
# \end{equation}
#
# where
#
# \begin{equation}
# f(x, y) = -\sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}
#
# Clear the analytical solution to this is
# \begin{equation}
# u(x, y) = \frac{1}{2 \pi^2} \sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/2 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/2 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc",

]
title_list = ["[20,20,20,20], BC loss weight = 2", "[64,64,64,64,64,64], BC loss weight = 2", 
              "[20,20,20,20], BC loss weight = 20", "[64,64,64,64,64,64], BC loss weight = 20",
              "[20,20,20,20], BC loss weight = 30", "[64,64,64,64,64,64], BC loss weight = 30",
              "[20,20,20,20], BC loss weight = 50","[64,64,64,64,64,64], BC loss weight = 50"]

plot_errors_in_grid(path_list, number_of_rows=4, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ---

# %% [markdown]
# ## Constant source term with complicated boundary condition

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \frac{\partial^2 u}{\partial x^2} + \frac{\partial^2 u}{\partial y^2} = 4
# \end{equation}
#
# with the boundary condition
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/2 weight_[20, 20, 20, 20]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/2 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[20, 20, 20, 20]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[20, 20, 20, 20]_Adam_7000_const_source",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source",

]
title_list = ["[20,20,20,20], BC loss weight = 2", "[64,64,64,64,64,64], BC loss weight = 2", 
              "[20,20,20,20], BC loss weight = 20", "[64,64,64,64,64,64], BC loss weight = 20",
              "[20,20,20,20], BC loss weight = 30", "[64,64,64,64,64,64], BC loss weight = 30",
              "[20,20,20,20], BC loss weight = 50","[64,64,64,64,64,64], BC loss weight = 50"]

plot_errors_in_grid(path_list, number_of_rows=4, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ---

# %% [markdown]
# ## Non-constant diffusion matrix

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \nabla \cdot (k(x,y) \nabla u(x,y)) = f(x,y)
# \end{equation}
# with
#
# \begin{equation}
# k(x,y) = \begin{pmatrix}
# x + 2 & xy^2\\
# xy^2 & y + 3
# \end{pmatrix}
# \end{equation}
#
# and
#
# \begin{equation}
# f(x,y) = 3y^4+9y^2+4x^2y+18y+4x+4
# \end{equation}
#
#
#
# with the boundary condition
#
# \begin{equation}
# u(x,y)=x^2+y^3
# \end{equation}
#
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2+y^3
# \end{equation}

# %%
path_list = [
    "../simulation_studies/composite_loss_simulation/outputs/2 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/2 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/20 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC",
     "../simulation_studies/composite_loss_simulation/outputs/50 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC",

]
title_list = ["[20,20,20,20], BC loss weight = 2", "[64,64,64,64,64,64], BC loss weight = 2", 
              "[20,20,20,20], BC loss weight = 20", "[64,64,64,64,64,64], BC loss weight = 20",
              "[20,20,20,20], BC loss weight = 30", "[64,64,64,64,64,64], BC loss weight = 30",
              "[20,20,20,20], BC loss weight = 50","[64,64,64,64,64,64], BC loss weight = 50"]

plot_errors_in_grid(path_list, number_of_rows=4, number_of_columns=2, title_list=title_list)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The weight depends on the poisson problem. To try to "strongly" enforce boundary conditions I will take the weight to be 30.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Where does the model fail?

# %% [markdown]
# Total epochs were 15000. Optimizer switch at epoch 7000 and weight 30

# %% [markdown]
# ## Fitting the eigenfunctions

# %% [markdown]
# I will try to solve the following poisson problem
# \begin{equation}
# \Delta u = f(x, y)
# \end{equation}
#
# with boundary conditions:
#
# \begin{equation}
# u(0, y) = u(1, y) = u(x, 0) = u(x, 1) = 0
# \end{equation}
#
# where
#
# \begin{equation}
# f(x, y) = -\sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}
#
# Clear the analytical solution to this is
# \begin{equation}
# u(x, y) = \frac{1}{2 \pi^2} \sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_eigenfunc"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [20,20,20,20], switch at epoch = 7000")

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [64, 64, 64, 64, 64, 64], switch at epoch = 7000")

# %% [markdown]
# ---

# %% [markdown]
# ## Constant source term with complicated boundary condition

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \frac{\partial^2 u}{\partial x^2} + \frac{\partial^2 u}{\partial y^2} = 4
# \end{equation}
#
# with the boundary condition
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2 + y^2
# \end{equation}

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_const_source"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [20,20,20,20], switch at epoch = 7000")

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_const_source"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [64, 64, 64, 64, 64, 64], switch at epoch = 7000")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Non-constant diffusion matrix

# %% [markdown]
# The solution \( u(x, y) \) for the Poisson equation
# \begin{equation}
# \nabla \cdot (k(x,y) \nabla u(x,y)) = f(x,y)
# \end{equation}
# with
#
# \begin{equation}
# k(x,y) = \begin{pmatrix}
# x + 2 & xy^2\\
# xy^2 & y + 3
# \end{pmatrix}
# \end{equation}
#
# and
#
# \begin{equation}
# f(x,y) = 3y^4+9y^2+4x^2y+18y+4x+4
# \end{equation}
#
#
#
# with the boundary condition
#
# \begin{equation}
# u(x,y)=x^2+y^3
# \end{equation}
#
#
# has analytical solution:
#
# \begin{equation}
# u(x, y) = x^2+y^3
# \end{equation}

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[20, 20, 20, 20]_Adam_7000_non_const_BC"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [20,20,20,20], switch at epoch = 7000")

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_non_const_BC"
plot_model_vs_analytical_error(path_to_model_dir, title="Composite loss, BC loss weight = 30, [64, 64, 64, 64, 64, 64], switch at epoch = 7000")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## How does models with embedding layer look

# %% [markdown]
# I will try to solve the following poisson problem
# \begin{equation}
# \Delta u = f(x, y)
# \end{equation}
#
# with boundary conditions:
#
# \begin{equation}
# u(0, y) = u(1, y) = u(x, 0) = u(x, 1) = 0
# \end{equation}
#
# where
#
# \begin{equation}
# f(x, y) = -\sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}
#
# Clear the analytical solution to this is
# \begin{equation}
# u(x, y) = \frac{1}{2 \pi^2} \sin\left(\pi x\right) \sin\left(\pi y\right)
# \end{equation}

# %%
path_to_model_dir = "../simulation_studies/composite_loss_simulation/outputs/30 weight_[64, 64, 64, 64, 64, 64]_Adam_7000_eigenfunc"
plot_model_vs_analytical_error(path_to_model_dir, title="No embedding layer")

# %%
path_to_model_dir = "../simulation_studies/model_v1_simulation/outputs/8 emb_[64, 64, 64, 64, 64, 64]_eigenfunc_Adam_5000"
plot_model_vs_analytical_error(path_to_model_dir, title="With embedding layer")
